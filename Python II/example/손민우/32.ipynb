# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
x = [1,2,3,4]
y = [1,4,9,16]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,'bo')

# %%
plt.plot(x,y,'b--')

# %%
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
plt.plot(x, y, 'ro')
plt.axis([0,6,0,20])
# Out:
# [0, 6, 0, 20]

# %%
import numpy as np

# %%
n = 20
x = np.random.rand(n)
y = np.random.rand(n)

plt.scatter(x,y,s=100,c='#a37ff1', marker='D')

# %%
ind = np.arange(4)

y=[4,6,5,8]
plt.bar(ind, y, width=0.3, bottom=5)
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
labels = 'frogs', 'hogs', 'dogs', 'logs'
sizes = [15,30,45,10]
explode=(0,0.1,0,0)
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.axis('equal')
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
v = np.random.uniform(0., 10., 100)
plt.hist(v)
# Out:
# (array([ 7., 11., 10., 12., 11.,  9., 10., 10., 10., 10.]),
#  array([0.21624661, 1.17450648, 2.13276634, 3.09102621, 4.04928607,
#         5.00754594, 5.9658058 , 6.92406567, 7.88232553, 8.8405854 ,
#         9.79884526]),
#  <a list of 10 Patch objects>)

# %%
spread = np.random.rand(50) * 100
center = np.ones(25) * 50
flier_high = np.random.rand(10) * 100 + 100
flier_low = np.random.rand(10) * -100
data = np.concatenate((spread, center, flier_high, flier_low), 0)
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xadf36b0>,
#   <matplotlib.lines.Line2D at 0xadf3c30>],
#  'caps': [<matplotlib.lines.Line2D at 0xadf3e90>,
#   <matplotlib.lines.Line2D at 0xad99810>],
#  'boxes': [<matplotlib.lines.Line2D at 0xadf36d0>],
#  'medians': [<matplotlib.lines.Line2D at 0xae01390>],
#  'fliers': [<matplotlib.lines.Line2D at 0xae015f0>],
#  'means': []}

# %%
plt.boxplot(data,1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0xbafeaf0>,
#   <matplotlib.lines.Line2D at 0xbafead0>],
#  'caps': [<matplotlib.lines.Line2D at 0xbb12250>,
#   <matplotlib.lines.Line2D at 0xbb124b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0xbafeab0>],
#  'medians': [<matplotlib.lines.Line2D at 0xbb12770>],
#  'fliers': [<matplotlib.lines.Line2D at 0xbb12990>],
#  'means': []}

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
